# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset= sns.load_dataset('tips')

# %%
dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
xyz= dataset[[ 'total_bill', 'tip','size']]

# %%
xyz.corr
# Out:
# <bound method DataFrame.corr of      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]>

# %%
sns.heatmap(xyz.corr())
# Out:
# <Axes: >

# %%
sns.distplot(x = dataset['tip'], bins = 10)
# Out:
# C:\Users\Trupti Pawar\AppData\Local\Temp\ipykernel_61272\814517626.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset['tip'], bins = 10)
# <Axes: ylabel='Density'>

# %%
sns.distplot(dataset['tip'], bins = 10,kde=False)
# Out:
# C:\Users\Trupti Pawar\AppData\Local\Temp\ipykernel_61272\645245854.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['tip'], bins = 10,kde=False)
# <Axes: xlabel='tip'>

# %%
sns.jointplot(x = dataset['tip'], y = dataset['total_bill'], kind = 'scatter')

# %%
sns.jointplot(x = dataset['tip'], y = dataset['total_bill'], kind = 'hex')

# %%
sns.pairplot(dataset, hue='sex')

# %%
sns.pairplot(dataset)

# %%
sns.rugplot(dataset['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.barplot(x='sex', y='tip', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x='sex', y='tip', data=dataset, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.countplot(x='sex', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='sex', y='tip', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='sex', y='tip', data=dataset, hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x='sex', y='tip', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x='sex', y='tip', data=dataset, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='sex', y='tip', data=dataset, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='sex', y='tip', data=dataset, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='sex', y='tip', data=dataset, jitter=True, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.swarmplot(x='sex', y='tip', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.swarmplot(x='sex', y='tip', data=dataset, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>
